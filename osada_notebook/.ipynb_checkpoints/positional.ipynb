# %%
import math

import torch
import torch.nn as nn

import seaborn as sns
import matplotlib.pyplot as plt

# %%
class PositionalEncoding(nn.Module):
    """Positional Encoding."""

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)
        )
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer("pe", pe)

    def forward(self, x):
        """PositionalEncodingを適用."""

        x = x + self.pe[: x.size(0), :]
        return self.dropout(x)

# %%
d_model = 512
dropout=0.1
max_len=5000

dropout = nn.Dropout(p=dropout)

pe = torch.zeros(max_len, d_model)
position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
div_term = torch.exp(
torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)
)
pe[:, 0::2] = torch.sin(position * div_term)
pe[:, 1::2] = torch.cos(position * div_term)
pe = pe.unsqueeze(0).transpose(0, 1)
print('pe.shape: ', pe.shape)

plt.figure(figsize=(15, 5))
sns.heatmap(pe[:, 0, :].T)
plt.xlabel('position', fontsize=15)
plt.ylabel('dimension', fontsize=15)
# Out:
# pe.shape:  torch.Size([5000, 1, 512])
# Text(158.22222222222223, 0.5, 'dimension')

# %% [markdown]
# positionを固定してdimensionを観測してみる

# %%
plt.figure(figsize=(15, 5))

plt.plot(pe[300, :, :500].reshape(-1))  # pe[position, 0, dimension]
plt.xlabel('dimension', fontsize=15)
# Out:
# Text(0.5, 0, 'dimension')

# %% [markdown]
# dimension固定してpositionを観測してみる
# 横に線を引いた感じ

# %%
plt.figure(figsize=(15, 5))

# pe[position, 0, dimension]
plt.plot(pe[:1500, :, 200])
plt.xlabel('Position', fontsize=15)
# Out:
# Text(0.5, 0, 'Position')
